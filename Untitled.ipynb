# %% [markdown]
# <a href="https://colab.research.google.com/github/saipraneeth1511/Python/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
a=2
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
print(a|b)
print(a^b)
print(max(a,b))
print(min(a,b))
print(math.pi)
print(math.e)
print(math.sqrt(a))
print(math.exp(a))
print(a)
print(b)
r=5
area=math.pi*r**2
print(area)
l=2
b=3
area=l*b
print(area)
s=2
area=s**2
print(area)
b=2
h=4
area=0.5*b*h
print(area)
t=[10,20,30,40,50]
print(t)
print(t[0])
print(t[-1])
print(t[1:])
print(t[1:4])
print(t[:3])
print(t*2)
print(len(t))
print(max(t))
print(min(t))
print(sum(t))
s="Sai Praneeth"
print(s)
print(s[0])
print(s[-1])
print(s[1:])
print(s[1:4])
print(s[:4])
print(s.title())
print(s.capitalize())
print(s.upper())
print(s.lower())
print(s.swapcase())
print(s.casefold())
print(s.isdigit())
print(s.isalnum())
print(s.isdecimal())
A={1,2,3,4}
B={2,3,4,5}
print(A.union(B))
print(A.intersection(B))
print(A.issubset(B))
print(A.issuperset(B))
print(A.isdisjoint(B))
