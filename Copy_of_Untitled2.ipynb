# %% [markdown]
# <a href="https://colab.research.google.com/github/saipraneeth1511/Python/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr=np.array([1,2,3,4,5])
print(np.mean(arr))
print(np.median(arr))
print(np.std(arr))
print(np.var(arr))
from numpy import random
a=random.binomial(n=3,p=0.5,size=3)
print(a)
b=random.uniform(2,3)
print(b)
c=random.exponential(size=2,scale=3)
print(c)
d=random.rayleigh(size=2,scale=3)
print(d)
e=random.chisquare(df=2,size=3)
print(e)
import cmath
Z1=2+3j
Z2=3+3j
print(Z1+Z2)
print(Z1-Z2)
print(Z1*Z2)
print(Z1/Z2)
print(Z1**Z2)
print(cmath.polar(Z1))
print(cmath.phase(Z1))
import tensorflow as tf
a=tf.constant(2)
b=tf.constant(3)
print(tf.add(a,b))
print(tf.abs(a,b))
print(tf.multiply(a,b))
print(tf.divide(a,b))
import matplotlib.pyplot as plt
Marks=[60,70,80,90]
Subjects=["Maths","Science","Social","English"]
plt.bar(Subjects,Marks)
plt.show()
import matplotlib.pyplot as plt
Marks=[60,70,80,90]
Subjects=["Maths","Science","Social","English"]
plt.barh(Subjects,Marks)
plt.show()
data=[10,20,30,40,50]
plt.hist(data)
plt.show()
Cases=(60,70,80,90)
Days=("Monday","Tuesday",
"Wednesday","Thursday")
plt.bar(Cases,Days)
plt.show()
